# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhaiminulJamee/Ostad-AI-Engineering-Batch-5/blob/main/Module_3_3_(Assignment).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Question 1: Enumerate with List

# %%
fruits = ["apple", "banana", "cherry", "mango"]

for index, fruit in enumerate(fruits):
    print(index, fruit)
# Out:
# 0 apple
# 1 banana
# 2 cherry
# 3 mango

# %% [markdown]
# ## Question 2: Zip with Two Lists

# %%
students = ["Rahim", "Karim", "Ayesha"]
scores = [85, 90, 78]

for student, score in zip(students, scores):
    print(f"{student} scored {score}")
# Out:
# Rahim scored 85
# Karim scored 90
# Ayesha scored 78

# %% [markdown]
# ## Question 3: Tuple and Loop

# %%
subjects = ("Math", "Physics", "Chemistry", "Biology", "English")

for subject in subjects:
    print(subject)
# Out:
# Math
# Physics
# Chemistry
# Biology
# English

# %% [markdown]
# ## Question 4: Set Operations

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7}

# Common elements
common_elements = set1 & set2
print("Common elements:", common_elements)

# Unique elements of set1
unique_set1 = set1 - set2
print("Unique elements of set1:", unique_set1)
# Out:
# Common elements: {4, 5}
# Unique elements of set1: {1, 2, 3}

# %% [markdown]
# ## Question 5: Dictionary with Enumerate

# %%
marks = {
    "Math": 80,
    "Physics": 75,
    "Chemistry": 85
}

for index, (subject, mark) in enumerate(marks.items(), start=1):
    print(f"{index} {subject}: {mark}")
# Out:
# 1 Math: 80
# 2 Physics: 75
# 3 Chemistry: 85
