# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhaiminulJamee/Ostad-AI-Engineering-Batch-5/blob/main/Module_1_3_(Assignment).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Question 1: Basic Print**

# %%
print("Welcome to Python Programming!")
print("I am learning the basics.")
# Out:
# Welcome to Python Programming!
# I am learning the basics.

# %% [markdown]
# **Question 2: Print with Variables**

# %%
name = "Muhaiminul"
age = 25

print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Muhaiminul and I am 25 years old.

# %% [markdown]
# **Question 3: User Input**

# %%
name = input("Enter your name: ")
language = input("Enter your favorite programming language: ")

print(f"Hello {name}, your favorite language is {language}.")
# Out:
# Enter your name: Muhaiminul
# Enter your favorite programming language: Python
# Hello Muhaiminul, your favorite language is Python.

# %% [markdown]
# **Question 4: Type Casting (String to Integer)**

# %%
num1 = input("Enter first number: ")
num2 = input("Enter second number: ")

num1 = int(num1)
num2 = int(num2)

print("The sum is:", num1 + num2)
# Out:
# Enter first number: 10
# Enter second number: 20
# The sum is: 30

# %% [markdown]
# **Question 5: Simple Calculator**

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulo:", a % b)
# Out:
# Enter first number: 25
# Enter second number: 10
# Addition: 35
# Subtraction: 15
# Multiplication: 250
# Division: 2.5
# Floor Division: 2
# Modulo: 5
